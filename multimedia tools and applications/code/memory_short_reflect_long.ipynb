# %%
import os
import json
from datetime import datetime, timedelta
import numpy as np
from sentence_transformers import SentenceTransformer
import openai

# OpenAI API Key 설정 함수
def load_api_key(file_path="../api_key.txt"):
    """
    API Key를 파일에서 로드합니다.
    """
    try:
        with open(file_path, "r") as f:
            return f.read().strip()
    except FileNotFoundError:
        raise FileNotFoundError(f"API 키 파일이 {file_path}에 없습니다.")

# API Key 로드 및 설정
api_key = load_api_key()
openai.api_key = api_key

# %%
class Persona:
    """
    Persona 정보를 관리하는 클래스
    """
    def __init__(self):
        self.data = {
            "Age": "54  ",
            "Gender": "Female  ",
            "Existing Medical Conditions": "Breast cancer, depressed mood, insomnia, back pain  ",
            "Symptoms": "Difficulties sleeping, worsened back pain  ",
            "Experience": [
                "I was diagnosed with breast cancer during a routine examination",
                "I experienced a depressed mood and insomnia",
                "my back pain got worse impacting my sleep",
                "I started pain control and physical therapy",
                "I wanted to stop taking sleep medication"
            ]
        }

    def get_persona(self):
        """
        현재 정의된 persona 정보를 반환합니다.
        """
        return self.data

# %%
class ShortTermMemory:
    """
    Short-Term Memory를 관리하는 클래스
    """
    def __init__(self, reflection_threshold, max_memory_size, ltm, persona, output_file="../output/5min_short_term_persona0.json"):
        self.memory = {}
        self.recent_memory = []
        self.active_memory = []
        self.current_poignancy = reflection_threshold
        self.current_emotion_score = reflection_threshold
        self.reflection_threshold = reflection_threshold
        self.max_memory_size = max_memory_size
        self.ltm = ltm
        self.persona = persona  # Persona 객체
        self.output_file = output_file
        self.node_id_file = "../output/node_id.json"
        self.node_id = self.load_node_id()
        os.makedirs(os.path.dirname(self.output_file), exist_ok=True)

    def load_node_id(self):
        """
        이전에 저장된 node_id 값을 로드하거나 초기화합니다.
        """
        try:
            if os.path.exists(self.node_id_file):
                with open(self.node_id_file, "r", encoding="utf-8") as file:
                    return json.load(file).get("node_id", 0)
            else:
                return 0
        except Exception as e:
            print(f"Error loading node_id: {e}")
            return 0

    def save_node_id(self):
        """
        현재 node_id 값을 파일에 저장합니다.
        """
        try:
            with open(self.node_id_file, "w", encoding="utf-8") as file:
                json.dump({"node_id": self.node_id}, file, ensure_ascii=False, indent=4)
        except Exception as e:
            print(f"Error saving node_id: {e}")

    def add_observation(self, timestamp, description):
        """
        Observation 데이터를 추가하고 Reflection Trigger를 확인합니다.
        """
        try:
            # Persona 정보 가져오기
            persona_data = self.persona.get_persona()

            # 분석 수행 및 데이터 생성
            poignancy, emotion, emotion_score = self.analyze_with_gpt(description, persona_data)
            embedding = generate_embedding(description)

            # Observation 생성
            observation = {
                "node_id": self.node_id,
                "timestamp": timestamp.strftime("%Y-%m-%d %H:%M:%S"),
                "description": description,
                "embedding": embedding,
                "poignancy": poignancy,
                "emotion": emotion,
                "emotion_score": emotion_score
            }

            # 메모리에 저장
            self.memory[self.node_id] = observation
            self.recent_memory.append(observation)
            if len(self.recent_memory) > self.max_memory_size:
                self.recent_memory.pop(0)

            self.active_memory.append(observation)
            self.node_id += 1

            self.current_poignancy -= poignancy
            self.current_emotion_score -= emotion_score

            print(f"Poignancy Threshold: {self.current_poignancy}, Emotion Score Threshold: {self.current_emotion_score}")

            # Reflection Trigger 확인
            if self.current_poignancy <= 0 or self.current_emotion_score <= 0:
                print("\n=== Reflection Triggered ===")
                generate_reflection(self.recent_memory, self.reflection_threshold, self.ltm)
                self.current_poignancy = self.reflection_threshold
                self.current_emotion_score = self.reflection_threshold
                self.active_memory = []

            # 메모리를 파일에 저장
            self.save_to_file()
            self.save_node_id()

        except Exception as e:
            print(f"Error adding observation: {description}. Exception: {e}")

    def analyze_with_gpt(self, description, persona_data):
        """
        GPT를 호출하여 Observation 데이터를 분석합니다.
        """
        persona_text = (
            f"Persona Information:\n"
            f"Age: {persona_data['Age']}\n"
            f"Gender: {persona_data['Gender']}\n"
            f"Existing Medical Conditions: {persona_data['Existing Medical Conditions']}\n"
            f"Symptoms: {persona_data['Symptoms']}\n"
            f"Experience: {', '.join(persona_data['Experience'])}\n"
        )

        prompt = f"""
        {persona_text}

        On a scale of 1 to 10, where:
        - 1 represents a mundane event (e.g., brushing teeth, making bed)
        - 10 represents an extremely poignant event (e.g., a breakup, college acceptance)

        Please analyze the following memory and provide:
        1. Poignancy score (1-10).
        2. The primary emotion (choose only from: joy, sadness, anger, fear, anticipation, surprise, trust, disgust).
        3. The intensity of the emotion (1-10).

        Memory: "{description}"
        Respond with a JSON object containing the keys: "poignancy", "emotion", and "emotion_score".
        The "emotion" must strictly be one of the 8 options provided. If the memory does not clearly align with one emotion, select the closest matching option from the list.
        """
        valid_emotions = ["joy", "sadness", "anger", "fear", "anticipation", "surprise", "trust", "disgust"]

        max_retries = 50
        for attempt in range(max_retries):
            try:
                print(f"Sending request to OpenAI API... (Attempt {attempt + 1})")
                response = openai.chat.completions.create(
                    model="gpt-4o-mini",
                    messages=[{"role": "user", "content": prompt}],
                    temperature=0.2,
                    top_p=0.8
                )
                generated_text = response.choices[0].message.content.strip()
                print(f"Generated Text: {generated_text}")

                if generated_text.startswith("```json"):
                    generated_text = generated_text[7:-3].strip()

                result = json.loads(generated_text)
                emotion = result["emotion"]

                if emotion in valid_emotions:
                    return result["poignancy"], emotion, result["emotion_score"]
                else:
                    print(f"Invalid emotion detected: {emotion}. Retrying...")
            except Exception as e:
                print(f"Error analyzing with GPT: {e}")

        print("Max retries reached. Returning default values.")
        return 5, "neutral", 5

    def save_to_file(self):
        """
        Short-Term Memory 데이터를 파일에 저장합니다.
        """
        try:
            with open(self.output_file, "w", encoding="utf-8") as file:
                json.dump(self.memory, file, ensure_ascii=False, indent=4)
        except Exception as e:
            print(f"Error writing to file: {e}")

# %%
def generate_embedding(text):
    """
    텍스트의 임베딩을 생성합니다.
    """
    try:
        response = openai.embeddings.create(
            input=[text],
            model="text-embedding-ada-002"
        )
        return response.data[0].embedding
    except Exception as e:
        print(f"Error generating embedding: {e}")
        return []


def generate_questions(memory):
    """
    최근 Observation 데이터를 기반으로 Reflective 질문을 생성합니다.
    """
    memory_text = "\n".join(
        [f"Timestamp: {m['timestamp']}, Description: {m['description']}" for m in memory]
    )
    prompt = f"""
    Statements:
    {memory_text}

    Based on the above statements, what are the 3 most important high-level questions we can ask to understand the behavior or motivations behind these observations?

    Provide the questions in a numbered list, without explanations.
    """
    try:
        response = openai.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
            top_p=0.8
        )
        return [q.strip() for q in response.choices[0].message.content.strip().split("\n") if q.strip()]
    except Exception as e:
        print(f"Error generating questions: {e}")
        return []


def find_relevant_shortterms(question, memory):
    """
    질문에 적합한 Short-Term Memory 5개를 찾습니다.
    """
    question_embedding = generate_embedding(question)
    similarities = []
    for m in memory:
        if "embedding" in m and m["embedding"]:
            similarity = np.dot(question_embedding, m["embedding"]) / (
                np.linalg.norm(question_embedding) * np.linalg.norm(m["embedding"]))
            similarities.append((similarity, m))
    similarities.sort(reverse=True, key=lambda x: x[0])  # 유사도 기준으로 정렬
    return [item[1] for item in similarities[:5]]  # 상위 5개 반환


def generate_reflection(stm_memory, reflection_threshold, ltm):
    """
    Reflection을 생성하고 Long-Term Memory에 저장합니다.
    """
    # Persona 정보 가져오기
    persona_data = persona.get_persona()
    persona_text = (
        f"Age: {persona_data['Age']}\n"
        f"Gender: {persona_data['Gender']}\n"
        f"Existing Medical Conditions: {persona_data['Existing Medical Conditions']}\n"
        f"Symptoms: {persona_data['Symptoms']}\n"
        f"Experience: {', '.join(persona_data['Experience'])}\n"
    )
    
    recent_memory = list(stm_memory)  # active_memory 사용
    questions = generate_questions(recent_memory)

    reflections = []
    for question in questions:
        relevant_shortterms = find_relevant_shortterms(question, recent_memory)

        memory_text = "\n".join(
            [f"Timestamp: {m['timestamp']}, Description: {m['description']}" for m in relevant_shortterms]
        )
        prompt = f"""
        Persona Information:
        {persona_text}

        Relevant Observations:
        {memory_text}

        Question:
        {question}

        Imagine you are experiencing the situation described above. Reflect on your thoughts and feelings in response to the question. Use a personal and conversational tone, avoiding specific time references like "last night" or "this morning." Focus on expressing your current thoughts and emotions clearly in 2-3 sentences, as if journaling or sharing with a trusted friend.
        """
        try:
            response = openai.chat.completions.create(
                model="gpt-4o-mini",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.7,
                top_p=0.8
            )
            reflection = response.choices[0].message.content.strip()

            # Reflection 분석 및 데이터 추가
            poignancy, emotion, emotion_score = stm.analyze_with_gpt(reflection, persona_data)
            embedding = generate_embedding(reflection)

            # Reflection의 Timestamp를 가장 최근 Short-Term Memory의 Timestamp로 설정
            timestamp = recent_memory[-1]['timestamp'] if recent_memory else datetime.now().strftime("%Y-%m-%d %H:%M:%S")

            reflection_data = {
                "reflection": reflection,
                "timestamp": timestamp,
                "poignancy": poignancy,
                "emotion": emotion,
                "emotion_score": emotion_score,
                "embedding": embedding,
                "related_shortterms": relevant_shortterms,
                "questions": questions
            }

            # Long-Term Memory에 저장
            ltm.add_reflection(reflection_data)
            reflections.append(reflection_data)

        except Exception as e:
            print(f"Error generating reflection: {e}")

    return reflections

# %%
class LongTermMemory:
    """
    Long-Term Memory를 관리하는 클래스
    """
    def __init__(self, output_file="../output/5min_long_term_persona0.json"):
        self.memory = {}
        self.node_id = 0
        self.output_file = output_file
        os.makedirs(os.path.dirname(self.output_file), exist_ok=True)

    def add_reflection(self, reflection_data):
        """
        Reflection 데이터를 저장합니다.
        """
        self.memory[self.node_id] = reflection_data
        self.node_id += 1
        self.save_to_file()

    def save_to_file(self):
        """
        Long-Term Memory 데이터를 파일에 저장합니다.
        """
        try:
            with open(self.output_file, "w", encoding="utf-8") as file:
                json.dump(self.memory, file, ensure_ascii=False, indent=4)
        except Exception as e:
            print(f"Error writing to file: {e}")

    def print_memory(self):
        """
        Long-Term Memory 데이터를 출력합니다.
        """
        print("\n=== Long-Term Memory ===")
        for node_id, reflection in self.memory.items():
            print(reflection)

# %%
# Main 실행
if __name__ == "__main__":
    persona = Persona()
    ltm = LongTermMemory(output_file="../output/5min_long_term_persona0.json")
    stm = ShortTermMemory(reflection_threshold=150, max_memory_size=100, ltm=ltm, persona=persona)

    # 단일 JSON 파일 경로
    json_file_path = "../data/dummy_dataset/final_dummy_data_0.json"

    try:
        print(f"Processing file: {json_file_path}")
        with open(json_file_path, "r", encoding="utf-8") as file:
            data = json.load(file)
            for entry in data:
                timestamp = datetime.strptime(entry["timestamp"], "%Y.%m.%d.%H.%M.%S")
                description = entry["activity"]
                stm.add_observation(timestamp, description)

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Processing file: ../data/dummy_dataset/final_dummy_data_0.json
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 147, Emotion Score Threshold: 145
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 143, Emotion Score Threshold: 139
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 140, Emotion Score Threshold: 135
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 137, Emotion Score Threshold: 131
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 134, Emotion Score Threshold: 126
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 131, Emotion Score Threshold: 122
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 127, Emotion Score Threshold: 117
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 124, Emotion Score Threshold: 112
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 120, Emotion Score Threshold: 106
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 116, Emotion Score Threshold: 100
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 112, Emotion Score Threshold: 94
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 109, Emotion Score Threshold: 90
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 106, Emotion Score Threshold: 85
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 103, Emotion Score Threshold: 81
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 100, Emotion Score Threshold: 76
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 97, Emotion Score Threshold: 71
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 94, Emotion Score Threshold: 67
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 91, Emotion Score Threshold: 62
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 88, Emotion Score Threshold: 57
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 85, Emotion Score Threshold: 52
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 82, Emotion Score Threshold: 48
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 79, Emotion Score Threshold: 43
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 76, Emotion Score Threshold: 38
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 73, Emotion Score Threshold: 33
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 70, Emotion Score Threshold: 28
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 67, Emotion Score Threshold: 23
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 63, Emotion Score Threshold: 17
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 60, Emotion Score Threshold: 12
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 57, Emotion Score Threshold: 8
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 54, Emotion Score Threshold: 3
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 50, Emotion Score Threshold: -3
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 8,
#     "emotion": "sadness",
#     "emotion_score": 9
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 8,
#     "emotion": "sadness",
#     "emotion_score": 9
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "anticipation",
#     "emotion_score": 7
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 147, Emotion Score Threshold: 146
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 144, Emotion Score Threshold: 141
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 140, Emotion Score Threshold: 135
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 136, Emotion Score Threshold: 129
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 133, Emotion Score Threshold: 124
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 127, Emotion Score Threshold: 117
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 5,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 122, Emotion Score Threshold: 111
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 119, Emotion Score Threshold: 107
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "sadness",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 117, Emotion Score Threshold: 104
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 113, Emotion Score Threshold: 98
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 109, Emotion Score Threshold: 93
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 105, Emotion Score Threshold: 88
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "trust",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 103, Emotion Score Threshold: 85
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 99, Emotion Score Threshold: 80
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 96, Emotion Score Threshold: 76
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 93, Emotion Score Threshold: 72
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 90, Emotion Score Threshold: 68
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 86, Emotion Score Threshold: 63
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "anticipation",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 84, Emotion Score Threshold: 60
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 81, Emotion Score Threshold: 56
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "anticipation",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 79, Emotion Score Threshold: 53
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 77, Emotion Score Threshold: 50
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "surprise",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 74, Emotion Score Threshold: 46
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "joy",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 70, Emotion Score Threshold: 40
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "anticipation",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 66, Emotion Score Threshold: 34
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 63, Emotion Score Threshold: 29
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 60, Emotion Score Threshold: 24
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "fear",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 58, Emotion Score Threshold: 21
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 55, Emotion Score Threshold: 16
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 52, Emotion Score Threshold: 12
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 49, Emotion Score Threshold: 8
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 47, Emotion Score Threshold: 5
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 43, Emotion Score Threshold: -1
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 8,
#     "emotion": "sadness",
#     "emotion_score": 9
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 8,
#   "emotion": "sadness",
#   "emotion_score": 9
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 147, Emotion Score Threshold: 146
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 144, Emotion Score Threshold: 142
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 141, Emotion Score Threshold: 138
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "joy",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 137, Emotion Score Threshold: 132
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 134, Emotion Score Threshold: 128
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "anticipation",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 130, Emotion Score Threshold: 122
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 126, Emotion Score Threshold: 117
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 123, Emotion Score Threshold: 113
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "anticipation",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 121, Emotion Score Threshold: 110
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 118, Emotion Score Threshold: 106
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 115, Emotion Score Threshold: 102
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "joy",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 112, Emotion Score Threshold: 97
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 109, Emotion Score Threshold: 93
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "joy",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 106, Emotion Score Threshold: 88
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "surprise",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 104, Emotion Score Threshold: 84
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 5,
#   "emotion": "anticipation",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 99, Emotion Score Threshold: 78
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 96, Emotion Score Threshold: 74
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "trust",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 90, Emotion Score Threshold: 67
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 87, Emotion Score Threshold: 63
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 83, Emotion Score Threshold: 57
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 77, Emotion Score Threshold: 50
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 73, Emotion Score Threshold: 44
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "sadness",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 67, Emotion Score Threshold: 37
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 64, Emotion Score Threshold: 33
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "sadness",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 62, Emotion Score Threshold: 30
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "sadness",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 60, Emotion Score Threshold: 27
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 58, Emotion Score Threshold: 24
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 55, Emotion Score Threshold: 19
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 53, Emotion Score Threshold: 16
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 50, Emotion Score Threshold: 12
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 46, Emotion Score Threshold: 6
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "joy",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 44, Emotion Score Threshold: 2
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "sadness",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 42, Emotion Score Threshold: -1
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 8,
#   "emotion": "sadness",
#   "emotion_score": 9
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 8,
#   "emotion": "sadness",
#   "emotion_score": 9
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 147, Emotion Score Threshold: 145
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 144, Emotion Score Threshold: 141
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "sadness",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 142, Emotion Score Threshold: 138
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "sadness",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 140, Emotion Score Threshold: 135
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 137, Emotion Score Threshold: 131
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 134, Emotion Score Threshold: 127
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 131, Emotion Score Threshold: 123
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 128, Emotion Score Threshold: 119
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "anticipation",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 124, Emotion Score Threshold: 114
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 121, Emotion Score Threshold: 110
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 117, Emotion Score Threshold: 105
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 113, Emotion Score Threshold: 99
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "trust",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 107, Emotion Score Threshold: 92
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "fear",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 101, Emotion Score Threshold: 85
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 98, Emotion Score Threshold: 80
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 94, Emotion Score Threshold: 74
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "trust",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 88, Emotion Score Threshold: 67
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 82, Emotion Score Threshold: 60
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 78, Emotion Score Threshold: 54
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 5,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 73, Emotion Score Threshold: 48
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 70, Emotion Score Threshold: 44
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "surprise",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 67, Emotion Score Threshold: 40
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "joy",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 63, Emotion Score Threshold: 34
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 59, Emotion Score Threshold: 29
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 55, Emotion Score Threshold: 23
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 51, Emotion Score Threshold: 17
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 48, Emotion Score Threshold: 13
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 45, Emotion Score Threshold: 8
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 41, Emotion Score Threshold: 2
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 37, Emotion Score Threshold: -4
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "sadness",
#   "emotion_score": 8
# }
# ```
# Poignancy Threshold: 143, Emotion Score Threshold: 142
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "anticipation",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 139, Emotion Score Threshold: 136
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "anticipation",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 137, Emotion Score Threshold: 133
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 133, Emotion Score Threshold: 127
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 130, Emotion Score Threshold: 122
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "sadness",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 124, Emotion Score Threshold: 115
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "fear",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 121, Emotion Score Threshold: 111
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 117, Emotion Score Threshold: 106
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "anticipation",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 114, Emotion Score Threshold: 102
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "sadness",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 112, Emotion Score Threshold: 99
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 108, Emotion Score Threshold: 94
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "sadness",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 106, Emotion Score Threshold: 91
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "sadness",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 104, Emotion Score Threshold: 88
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 98, Emotion Score Threshold: 81
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 95, Emotion Score Threshold: 77
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 91, Emotion Score Threshold: 72
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "sadness",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 89, Emotion Score Threshold: 69
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 86, Emotion Score Threshold: 64
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 83, Emotion Score Threshold: 60
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 81, Emotion Score Threshold: 57
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 77, Emotion Score Threshold: 52
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 71, Emotion Score Threshold: 45
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 69, Emotion Score Threshold: 42
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 66, Emotion Score Threshold: 38
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 63, Emotion Score Threshold: 34
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "anticipation",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 59, Emotion Score Threshold: 28
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 56, Emotion Score Threshold: 24
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 52, Emotion Score Threshold: 19
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 48, Emotion Score Threshold: 14
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 45, Emotion Score Threshold: 9
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 42, Emotion Score Threshold: 4
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 39, Emotion Score Threshold: 0
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 147, Emotion Score Threshold: 146
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 1,
#   "emotion": "trust",
#   "emotion_score": 2
# }
# ```
# Poignancy Threshold: 146, Emotion Score Threshold: 144
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "anticipation",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 144, Emotion Score Threshold: 140
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "trust",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 142, Emotion Score Threshold: 137
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 139, Emotion Score Threshold: 133
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 1,
#   "emotion": "trust",
#   "emotion_score": 2
# }
# ```
# Poignancy Threshold: 138, Emotion Score Threshold: 131
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "trust",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 136, Emotion Score Threshold: 128
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 133, Emotion Score Threshold: 124
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "trust",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 131, Emotion Score Threshold: 121
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 129, Emotion Score Threshold: 118
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 126, Emotion Score Threshold: 113
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "trust",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 124, Emotion Score Threshold: 110
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "joy",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 120, Emotion Score Threshold: 104
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 117, Emotion Score Threshold: 100
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 113, Emotion Score Threshold: 94
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 109, Emotion Score Threshold: 89
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 106, Emotion Score Threshold: 84
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 104, Emotion Score Threshold: 81
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "sadness",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 102, Emotion Score Threshold: 78
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 99, Emotion Score Threshold: 74
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "joy",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 95, Emotion Score Threshold: 68
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 91, Emotion Score Threshold: 62
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 87, Emotion Score Threshold: 56
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Poignancy Threshold: 80, Emotion Score Threshold: 48
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "anticipation",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 77, Emotion Score Threshold: 43
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 73, Emotion Score Threshold: 38
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "joy",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 70, Emotion Score Threshold: 32
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 66, Emotion Score Threshold: 27
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 63, Emotion Score Threshold: 23
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 59, Emotion Score Threshold: 17
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 56, Emotion Score Threshold: 12
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 52, Emotion Score Threshold: 6
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 49, Emotion Score Threshold: 1
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 46, Emotion Score Threshold: -3
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "trust",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "sadness",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "trust",
#     "emotion_score": 7
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "joy",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 144, Emotion Score Threshold: 143
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "sadness",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 142, Emotion Score Threshold: 140
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 138, Emotion Score Threshold: 135
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 134, Emotion Score Threshold: 130
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 130, Emotion Score Threshold: 125
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 5,
#     "emotion": "surprise",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 125, Emotion Score Threshold: 119
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "fear",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 121, Emotion Score Threshold: 113
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "anticipation",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 117, Emotion Score Threshold: 108
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 114, Emotion Score Threshold: 104
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 111, Emotion Score Threshold: 99
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 8,
#   "emotion": "sadness",
#   "emotion_score": 9
# }
# ```
# Poignancy Threshold: 103, Emotion Score Threshold: 90
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 100, Emotion Score Threshold: 86
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 5,
#     "emotion": "fear",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 95, Emotion Score Threshold: 79
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 92, Emotion Score Threshold: 74
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 89, Emotion Score Threshold: 69
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 87, Emotion Score Threshold: 66
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 84, Emotion Score Threshold: 61
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 81, Emotion Score Threshold: 57
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 78, Emotion Score Threshold: 53
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 75, Emotion Score Threshold: 48
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 72, Emotion Score Threshold: 44
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "trust",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 70, Emotion Score Threshold: 41
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 67, Emotion Score Threshold: 37
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 64, Emotion Score Threshold: 33
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 61, Emotion Score Threshold: 29
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "joy",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 58, Emotion Score Threshold: 24
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 55, Emotion Score Threshold: 20
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "sadness",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 52, Emotion Score Threshold: 16
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 49, Emotion Score Threshold: 12
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 46, Emotion Score Threshold: 7
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 1,
#   "emotion": "neutral",
#   "emotion_score": 1
# }
# ```
# Invalid emotion detected: neutral. Retrying...
# Sending request to OpenAI API... (Attempt 2)
# Generated Text: ```json
# {
#   "poignancy": 1,
#   "emotion": "neutral",
#   "emotion_score": 1
# }
# ```
# Invalid emotion detected: neutral. Retrying...
# Sending request to OpenAI API... (Attempt 3)
# Generated Text: ```json
# {
#     "poignancy": 1,
#     "emotion": "trust",
#     "emotion_score": 2
# }
# ```
# Poignancy Threshold: 45, Emotion Score Threshold: 5
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "trust",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 43, Emotion Score Threshold: 2
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 41, Emotion Score Threshold: -1
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "trust",
#     "emotion_score": 7
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "anticipation",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# ...
# }
# ```
# Poignancy Threshold: 81, Emotion Score Threshold: 59
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 75, Emotion Score Threshold: 52
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "trust",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 69, Emotion Score Threshold: 45
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 66, Emotion Score Threshold: 40
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "anticipation",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 64, Emotion Score Threshold: 36
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 5,
#     "emotion": "anticipation",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 59, Emotion Score Threshold: 30
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 56, Emotion Score Threshold: 25
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 52, Emotion Score Threshold: 20
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 49, Emotion Score Threshold: 15
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 46, Emotion Score Threshold: 10
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "trust",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 40, Emotion Score Threshold: 3
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 37, Emotion Score Threshold: -2
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "sadness",
#   "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "sadness",
#   "emotion_score": 7
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "trust",
#     "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 147, Emotion Score Threshold: 145
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "trust",
#     "emotion_score": 8
# }
# ```
# Poignancy Threshold: 140, Emotion Score Threshold: 137
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "anticipation",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 136, Emotion Score Threshold: 131
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "trust",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 130, Emotion Score Threshold: 124
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 128, Emotion Score Threshold: 120
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "anticipation",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 125, Emotion Score Threshold: 115
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 119, Emotion Score Threshold: 108
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "trust",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 113, Emotion Score Threshold: 101
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "trust",
#     "emotion_score": 3
# }
# ```
# Poignancy Threshold: 111, Emotion Score Threshold: 98
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 108, Emotion Score Threshold: 93
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 105, Emotion Score Threshold: 88
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 102, Emotion Score Threshold: 83
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "anticipation",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 96, Emotion Score Threshold: 76
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "trust",
#     "emotion_score": 8
# }
# ```
# Poignancy Threshold: 89, Emotion Score Threshold: 68
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 83, Emotion Score Threshold: 61
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "sadness",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 79, Emotion Score Threshold: 56
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 73, Emotion Score Threshold: 49
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 67, Emotion Score Threshold: 42
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "anticipation",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 61, Emotion Score Threshold: 35
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "anticipation",
#   "emotion_score": 8
# }
# ```
# Poignancy Threshold: 54, Emotion Score Threshold: 27
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 47, Emotion Score Threshold: 21
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "trust",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 41, Emotion Score Threshold: 14
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 35, Emotion Score Threshold: 7
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 5,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 30, Emotion Score Threshold: 1
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 26, Emotion Score Threshold: -5
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "sadness",
#   "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "trust",
#   "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "trust",
#   "emotion_score": 7
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "trust",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 144, Emotion Score Threshold: 143
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "anticipation",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 141, Emotion Score Threshold: 138
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "joy",
#   "emotion_score": 8
# }
# ```
# Poignancy Threshold: 134, Emotion Score Threshold: 130
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "anticipation",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 131, Emotion Score Threshold: 125
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "anticipation",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 128, Emotion Score Threshold: 120
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "sadness",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 122, Emotion Score Threshold: 113
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "sadness",
#   "emotion_score": 3
# }
# ```
# Poignancy Threshold: 120, Emotion Score Threshold: 110
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 4,
#     "emotion": "trust",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 116, Emotion Score Threshold: 105
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 112, Emotion Score Threshold: 100
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "trust",
#     "emotion_score": 8
# }
# ```
# Poignancy Threshold: 105, Emotion Score Threshold: 92
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "joy",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 99, Emotion Score Threshold: 85
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "trust",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 96, Emotion Score Threshold: 79
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 92, Emotion Score Threshold: 74
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 5,
#   "emotion": "anticipation",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 87, Emotion Score Threshold: 68
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 5,
#     "emotion": "sadness",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 82, Emotion Score Threshold: 62
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 78, Emotion Score Threshold: 56
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "anticipation",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 71, Emotion Score Threshold: 50
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "trust",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 68, Emotion Score Threshold: 45
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 65, Emotion Score Threshold: 40
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 7,
#     "emotion": "trust",
#     "emotion_score": 8
# }
# ```
# Poignancy Threshold: 58, Emotion Score Threshold: 32
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 55, Emotion Score Threshold: 28
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 52, Emotion Score Threshold: 23
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 2,
#   "emotion": "anticipation",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 50, Emotion Score Threshold: 19
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 5,
#   "emotion": "anticipation",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 45, Emotion Score Threshold: 13
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "anticipation",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 43, Emotion Score Threshold: 9
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 39, Emotion Score Threshold: 3
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 5,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 34, Emotion Score Threshold: -3
#
# === Reflection Triggered ===
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "sadness",
#   "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "sadness",
#   "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 7,
#   "emotion": "trust",
#   "emotion_score": 8
# }
# ```
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "sadness",
#   "emotion_score": 5
# }
# ```
# Poignancy Threshold: 146, Emotion Score Threshold: 145
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 3,
#   "emotion": "sadness",
#   "emotion_score": 4
# }
# ```
# Poignancy Threshold: 143, Emotion Score Threshold: 141
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 2,
#     "emotion": "anticipation",
#     "emotion_score": 4
# }
# ```
# Poignancy Threshold: 141, Emotion Score Threshold: 137
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 5,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 136, Emotion Score Threshold: 131
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 6,
#   "emotion": "sadness",
#   "emotion_score": 7
# }
# ```
# Poignancy Threshold: 130, Emotion Score Threshold: 124
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 6,
#     "emotion": "sadness",
#     "emotion_score": 7
# }
# ```
# Poignancy Threshold: 124, Emotion Score Threshold: 117
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 120, Emotion Score Threshold: 111
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 116, Emotion Score Threshold: 105
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 5,
#     "emotion": "anticipation",
#     "emotion_score": 6
# }
# ```
# Poignancy Threshold: 111, Emotion Score Threshold: 99
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#     "poignancy": 3,
#     "emotion": "anticipation",
#     "emotion_score": 5
# }
# ```
# Poignancy Threshold: 108, Emotion Score Threshold: 94
# Sending request to OpenAI API... (Attempt 1)
# Generated Text: ```json
# {
#   "poignancy": 4,
#   "emotion": "trust",
#   "emotion_score": 6
# }
# ```
# Poignancy Threshold: 104, Emotion Score Threshold: 88

# %%
import json
from collections import Counter

# 파일에서 데이터를 로드하는 함수
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# 감정 필드 확인 함수
def extract_and_check_emotions(file_path, valid_emotions):
    data = load_data(file_path)
    emotion_list = []

    # 모든 데이터에서 emotion 필드 추출
    for node_id, node in data.items():
        if 'emotion' in node:
            emotion_list.append(node['emotion'])

    # 고유 감정 값 및 카운트 계산
    unique_emotions = set(emotion_list)
    emotion_counts = Counter(emotion_list)

    # 8가지 감정 외의 값 확인
    invalid_emotions = unique_emotions - set(valid_emotions)

    return {
        "unique_emotions": unique_emotions,
        "emotion_counts": emotion_counts,
        "invalid_emotions": invalid_emotions
    }

# 8가지 감정 정의
valid_emotions = ['joy', 'sadness', 'anger', 'fear', 'anticipation', 'surprise', 'trust', 'disgust']

# Short-Term Memory 파일 경로 (예시)
short_term_path = "../output/5min_short_term_persona0.json"

# Long-Term Memory 파일 경로 (예시)
long_term_path = "../output/5min_long_term_persona0.json"

# Short-Term Memory 감정 확인
short_term_results = extract_and_check_emotions(short_term_path, valid_emotions)
print("Short-Term Memory:")
print("Unique Emotions:", short_term_results["unique_emotions"])
print("Emotion Counts:", short_term_results["emotion_counts"])
print("Invalid Emotions:", short_term_results["invalid_emotions"])
print()

# Long-Term Memory 감정 확인
long_term_results = extract_and_check_emotions(long_term_path, valid_emotions)
print("Long-Term Memory:")
print("Unique Emotions:", long_term_results["unique_emotions"])
print("Emotion Counts:", long_term_results["emotion_counts"])
print("Invalid Emotions:", long_term_results["invalid_emotions"])
# Out:
# Short-Term Memory:
# Unique Emotions: {'fear', 'trust', 'neutral', 'surprise', 'joy', 'disgust', 'anticipation', 'sadness'}
# Emotion Counts: Counter({'trust': 357, 'sadness': 269, 'anticipation': 223, 'joy': 77, 'fear': 17, 'surprise': 13, 'disgust': 3, 'neutral': 2})
# Invalid Emotions: {'neutral'}
#
# Long-Term Memory:
# Unique Emotions: {'fear', 'trust', 'joy', 'anticipation', 'sadness'}
# Emotion Counts: Counter({'sadness': 33, 'trust': 32, 'joy': 16, 'anticipation': 8, 'fear': 1})
# Invalid Emotions: set()

# %%
import json

# JSON 파일 경로
file_path = '../data/dummy_dataset/final_dummy_data_0.json'

# JSON 파일 읽기
with open(file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 'activity' 키의 개수 세기
activity_count = sum(1 for item in data if 'activity' in item)

print(f"'activity' 항목의 총 개수: {activity_count}")
# Out:
# 'activity' 항목의 총 개수: 961

# %%
# import json

# def merge_json_files(file1_path, file2_path, output_path):
#     """
#     두 개의 JSON 파일을 합쳐 하나의 파일로 저장합니다.

#     Args:
#         file1_path (str): 첫 번째 JSON 파일 경로
#         file2_path (str): 두 번째 JSON 파일 경로
#         output_path (str): 합쳐진 결과를 저장할 JSON 파일 경로
#     """
#     try:
#         # 첫 번째 JSON 파일 읽기
#         with open(file1_path, "r", encoding="utf-8") as file1:
#             data1 = json.load(file1)

#         # 두 번째 JSON 파일 읽기
#         with open(file2_path, "r", encoding="utf-8") as file2:
#             data2 = json.load(file2)

#         # 데이터 타입 확인 및 병합
#         if isinstance(data1, list) and isinstance(data2, list):
#             # 데이터가 리스트 형식이면 리스트 병합
#             merged_data = data1 + data2
#         elif isinstance(data1, dict) and isinstance(data2, dict):
#             # 데이터가 딕셔너리 형식이면 딕셔너리 병합
#             merged_data = {**data1, **data2}
#         else:
#             raise ValueError("두 JSON 파일의 데이터 형식이 서로 다르거나 지원되지 않습니다. (list 또는 dict만 지원)")

#         # 합쳐진 데이터를 새로운 파일에 저장
#         with open(output_path, "w", encoding="utf-8") as output_file:
#             json.dump(merged_data, output_file, ensure_ascii=False, indent=4)

#         print(f"JSON 파일이 성공적으로 병합되었습니다. 결과 파일 경로: {output_path}")

#     except Exception as e:
#         print(f"JSON 병합 중 오류 발생: {e}")

# # 예제 실행
# file1_path = "../data/dummy_dataset/5min_dummy_data_0.json"
# file2_path = "../data/dummy_dataset/5min_dummy_data_1.json"
# output_path = "../data/dummy_dataset/5min_dummy_data_merge.json"

# merge_json_files(file1_path, file2_path, output_path)

# %%
# import json

# # longterm_with_dialogue.json 파일 경로
# file_path = "../output/5min_long_term_persona0.json"
# output_file_path = "../output/reflections_persona0.txt"  # 출력 파일 경로

# def extract_reflections(file_path):
#     try:
#         # JSON 파일 읽기
#         with open(file_path, "r", encoding="utf-8") as file:
#             data = json.load(file)
        
#         reflections = {}
#         # reflection 필드가 있는 노드만 추출
#         for node_id, content in data.items():
#             if "reflection" in content:  # "reflection" 키가 있는지 확인
#                 reflections[node_id] = content["reflection"]
        
#         return reflections
#     except Exception as e:
#         print(f"파일 읽기 중 오류 발생: {e}")
#         return {}

# def save_reflections_to_txt(reflections, output_file_path):
#     try:
#         with open(output_file_path, "w", encoding="utf-8") as file:
#             for node_id, reflection in reflections.items():
#                 file.write(f"노드 ID: {node_id}\n")
#                 file.write(f"Reflection: {reflection}\n\n")
#         print(f"Reflection 데이터가 {output_file_path} 파일에 저장되었습니다.")
#     except Exception as e:
#         print(f"파일 저장 중 오류 발생: {e}")

# # reflection 데이터 추출
# reflections = extract_reflections(file_path)

# # reflection 데이터 출력 및 저장
# if reflections:
#     print("\n=== 추출된 Reflection ===")
#     for node_id, reflection in reflections.items():
#         print(f"노드 ID: {node_id}")
#         print(f"Reflection: {reflection}\n")
    
#     # Reflection 데이터를 txt 파일로 저장
#     save_reflections_to_txt(reflections, output_file_path)
# else:
#     print("Reflection 데이터가 없습니다.")
# Out:
# === 추출된 Reflection ===
# 노드 ID: 0
# Reflection: I find myself sleeping for such a long stretch because my body is just so exhausted from the constant battle with pain and the emotional toll of everything I'm going through. It feels like a much-needed escape from the anxiety and the heaviness of my situation, even if just for a little while. I can't help but feel a mix of relief and worry—relief that I'm finally getting some rest, but worry that I'm relying on sleep as a way to cope with everything else.
#
# 노드 ID: 1
# Reflection: Lately, I’ve been feeling a bit overwhelmed with everything going on—my battle with breast cancer, the persistent back pain, and the weight of my depressed mood. It’s like my body is telling me to rest, but I can't help but wonder if this prolonged sleep is just a way to escape or if it’s my mind and body trying to heal. I really want to find a balance, but it’s hard not to feel a little lost in all of this.
#
# 노드 ID: 2
# Reflection: Lately, I’ve been feeling a bit overwhelmed with everything going on. My sleep schedule seems to be out of sync with my daily responsibilities, making it hard to keep up with tasks and maintain a sense of normalcy. I wish I could find a way to balance my need for rest with the demands of my life, but the struggle with insomnia and pain just makes it all feel so much heavier.
#
# 노드 ID: 3
# Reflection: I feel so frustrated because my back pain keeps interrupting my sleep, making it impossible to feel rested. It's like a vicious cycle—when I wake up in pain, it only adds to my depressed mood and anxiety about not getting enough sleep. I just want to find a way to ease the tension and get a good night's rest without relying on medication.
#
# 노드 ID: 4
# Reflection: When I feel discomfort or tension in my body, I often find myself instinctively trying to relax and ease the tightness. Stretching helps me a lot; it’s like a gentle reminder to listen to my body and give it the care it needs. I wish I could find a way to do this without relying on medication, as I want to feel more in control of my body and my well-being.
#
# 노드 ID: 5
# Reflection: As I slowly wake up, the persistent back pain feels like a heavy weight, pulling me deeper into a fog of frustration and sadness. The dim light filtering through the curtains creates an almost surreal atmosphere, making me acutely aware of my vulnerability and the struggle to find comfort in this space. It’s as if my mind is caught in a tug-of-war between wanting to escape the discomfort and yearning for a moment of peace, leaving me feeling both restless and overwhelmed.
#
# 노드 ID: 6
# Reflection: I feel so frustrated and overwhelmed when I wake up from pain, especially with my back acting up. It’s like my mind races with worries about my health and the struggles I've been through, making it impossible to relax and drift back to sleep. I just want to find a way to ease the pain and quiet my thoughts so I can rest peacefully again.
#
# 노드 ID: 7
# Reflection: I'm finding that my back pain really gets in the way of my ability to unwind and relax. Even when I try to stretch or massage my shoulders, the discomfort lingers and makes me feel restless and frustrated. It’s like my body is holding onto this tension, and it’s so hard to calm my mind when I’m physically uncomfortable.
#
# 노드 ID: 8
# Reflection: As I lay there, feeling the frustration of restlessness wash over me, I couldn't help but feel a deep sense of vulnerability. The pain in my back reminded me of my struggles, making me acutely aware of my limitations and the weight of my circumstances. It's disheartening to feel so trapped in this cycle of discomfort and sleeplessness, and I long for a moment of peace that seems just out of reach.
#
# 노드 ID: 9
# Reflection: I woke up in the middle of the night, and the back pain was just unbearable. It felt like my body was holding me hostage, and all I could think about was the frustration of being wide awake while everyone else was asleep. I tried to relax and ease the tension, but the restlessness just made it worse, and it felt like I was stuck in this endless cycle of discomfort and anxiety.
#
# 노드 ID: 10
# Reflection: As I stretched and adjusted my position, I could feel the tension slowly melting away, and it was such a relief. Each little increase in flexibility brought a sense of comfort that was hard to describe, almost like a gentle reminder that my body is still capable of finding ease amidst the pain. It felt like a nurturing moment for myself, and I found a bit of peace in that simple act of caring for my body.
#
# 노드 ID: 11
# Reflection: As I lay there, I felt a wave of frustration wash over me, the restlessness creeping in and making it so hard to settle my mind. But then, as I adjusted my pillow, I started to notice a gentle shift within me—a sense of relaxation beginning to spread through my body. It was a small but significant reminder that even in these tough moments, there’s potential for calm to break through the chaos.
#
# 노드 ID: 12
# Reflection: Lately, I've been feeling this constant restlessness that makes it hard to settle down and find comfort in bed. My back pain has been flaring up, and it's almost like my body is sending me signals to stretch and shift positions to find some relief. It’s frustrating because I just want to sleep, but instead, I end up adjusting my pillow and mattress, hoping for a moment of peace.
#
# 노드 ID: 13
# Reflection: I find that the quietness of my surroundings really plays a huge role in how I relax and drift off to sleep. When the house is still, I can almost feel the tension in my body ease away, and I can focus on my breathing without distractions. It’s those peaceful moments that help me find a little calm amidst everything I’m dealing with, even if it’s just for a short while.
#
# 노드 ID: 14
# Reflection: I can’t shake this feeling of restlessness, and it’s like my mind is racing with thoughts about my upcoming appointments. The weight of uncertainty and the anxiety of what those meetings might bring just adds to my already heavy heart. Sometimes, I wish I could quiet my mind and just find a moment of peace, but it feels like I’m stuck in this loop of worry and frustration.
#
# 노드 ID: 15
# Reflection: I’ve been really trying to find that peaceful place between being awake and drifting off, and I can feel the tension start to melt away when I focus on my breathing. It’s like each deep breath pulls me further into relaxation, and I can almost sense my body surrendering to the mattress. But I still feel that nagging back pain, reminding me that it’s not always easy to let go completely.
#
# 노드 ID: 16
# Reflection: As I settle into a moment of rest, I can feel a gentle wave of relaxation washing over me, easing the tension in my back and quieting the racing thoughts in my mind. The stillness around me feels comforting, almost like a warm embrace, allowing me to breathe deeply and appreciate the peace I’ve longed for. In these precious moments, I find a sense of clarity and hope, reminding me that I can reclaim some control over my well-being amidst the challenges I face.
#
# 노드 ID: 17
# Reflection: Preparing and sipping herbal tea has become a comforting ritual for me, a moment of peace amid the chaos of my thoughts and physical discomfort. The warmth of the tea and the soothing aroma of the herbs help to calm my mind, making it easier to let go of the day's worries and settle into a more relaxed state. It's like a gentle hug for my spirit, guiding me toward a more restful night despite the challenges I face.
#
# 노드 ID: 18
# Reflection: I found myself caught in this frustrating cycle of wakefulness, where my mind raced with thoughts about everything from my health to the discomfort in my back. Each time I tried to settle back into sleep, it felt like my body was rebelling against me, making it hard to find that peaceful state again. I just wish I could let go and drift off without all these nagging worries and aches pulling me back into consciousness.
#
# 노드 ID: 19
# Reflection: As I lay there, enveloped in the stillness, I could feel the gentle tug of wakefulness, yet I was so relaxed, almost cradled by the mattress beneath me. The quietness around me was soothing, and I noticed how the soft sensation of the air made everything feel lighter, easing the weight of my back pain and worries. It was a moment where my senses wrapped around me like a warm blanket, bringing a sense of peace that I desperately needed.
#
# 노드 ID: 20
# Reflection: As I lay in bed, my mind started to wander through the events of the day, and I realized that my thoughts were like a heavy blanket, weighing down my ability to relax. The worries and reflections seemed to swirl around, making it hard to settle into a peaceful sleep. Even as the morning light began to filter in, I felt a mix of calm from the cool air and the lingering tension from my restless thoughts, reminding me how intertwined my emotions are with my sleep quality.
#
# 노드 ID: 21
# Reflection: I’ve found that starting my day with gentle stretches really helps set a peaceful tone. It’s like I can feel the tension melting away, and I appreciate those quiet moments where I can just breathe and enjoy the cool air around me. It’s comforting to embrace that sense of relaxation, especially when I’m dealing with so much.
#
# 노드 ID: 22
# Reflection: Sensory experiences really enhance the little moments in my day, like sipping tea or enjoying breakfast. The warmth of the cup in my hands and the comforting aroma of the tea wrap around me, making me feel grounded and present. Each bite of my meal is a reminder of the simple pleasures in life, and they help lift my spirits, even if just a little, amidst everything I’m going through.
#
# 노드 ID: 23
# Reflection: I've been really noticing how the coolness of the air and the gentle light coming into the room can shift my mood. It feels refreshing and invigorating, almost like a gentle reminder that there’s beauty in each day, even when I'm struggling with my back pain and insomnia. Those little moments of awareness help me feel more grounded and connected, making it easier to face the challenges ahead.
#
# 노드 ID: 24
# Reflection: As I slowly wake up, I feel this strange mix of confusion and relief. The vivid colors and indistinct voices linger in my mind, almost like remnants of a dream that I can't quite grasp, leaving me feeling both curious and a bit unsettled. It's a reminder of the heaviness I carry during the day, but in this moment, there's a fleeting sense of peace before reality sets in again.
#
# 노드 ID: 25
# Reflection: Starting my day with gentle stretches really sets a positive tone for me, helping to ease some of the back pain and bringing a sense of calm. Feeling the morning light fill the room lifts my spirits, while enjoying a fresh meal nourishes not just my body but also my mind. It’s these little moments that help me feel more grounded and motivated to face the day, despite the challenges I’m dealing with.
#
# 노드 ID: 26
# Reflection: As I move through my morning routine, the brightness of the light streaming into the room feels like a gentle nudge, awakening my senses and lifting my spirits. The fresh air wraps around me, bringing a sense of calm that helps ease the weight of my worries, while the simple pleasure of a nourishing meal nourishes not just my body but my mood too. These little moments of connection with my surroundings remind me that there’s still beauty and comfort to be found, even amidst the challenges I face.
#
# 노드 ID: 27
# Reflection: I've been really appreciating the little things lately, like the crispness of the air and the way the morning light fills the room. Taking a moment to enjoy my breakfast and savor the flavors feels grounding, almost like a small celebration of the day ahead. It’s these simple routines that help me feel more present and connected, even when things feel heavy.
#
# 노드 ID: 28
# Reflection: I've noticed that my sensory experiences have a profound impact on how I perceive my surroundings and tackle daily tasks. The familiar scents can bring me a sense of comfort, almost like a warm hug, while vibrant imagery catches my eye and sparks a bit of joy amidst the heaviness I sometimes feel. It’s like these little moments of beauty and familiarity help lift my mood and make even the simplest activities feel more manageable.
#
# 노드 ID: 29
# Reflection: I've been feeling so much more relaxed lately, especially after stretching and moving my body. It’s amazing how releasing tension from my muscles seems to lift my mood and clear my mind. I really appreciate those moments when I can feel the flexibility returning and the heaviness of my worries easing up; it’s like a little reminder that I can find peace even amidst the challenges I’m facing.
#
# 노드 ID: 30
# Reflection: I've found that surrounding myself with familiar scents really brings me comfort, almost like a warm hug on tough days. I also enjoy taking time to reflect on the things I read, as it helps me feel connected and engaged, even when my mood dips. Incorporating gentle music into my routine adds a soothing layer, making my pain management sessions feel a bit more bearable and peaceful.
#
# 노드 ID: 31
# Reflection: Lately, I've found myself really drawn to the vibrant colors and engaging visuals around me, almost as if they’re pulling me into a different world. It’s comforting to notice the details in the images; they seem to lift my mood and distract me from the pain. I feel a sense of peace when I immerse myself in these sensory experiences, even if just for a moment, allowing me to escape the heaviness of my thoughts and the struggles I face.
#
# 노드 ID: 32
# Reflection: As I sit here in the hospital, I can't help but feel a mix of anxiety and comfort from the people around me. The familiar faces of the staff and the gentle conversations with fellow patients make this place feel a bit less daunting, reminding me that I’m not alone in this struggle. Yet, I also sense a heaviness in the air, a shared understanding of our battles, which sometimes makes me feel even more isolated in my own pain and worries.
#
# 노드 ID: 33
# Reflection: I find myself gravitating towards media that feels comforting and engaging, especially since I’ve been dealing with so much lately. I often choose articles or shows that inspire hope or provide a sense of connection, perhaps because they distract me from my worries and lift my mood a bit. Magazines with personal stories or insights resonate deeply, as they remind me that I’m not alone in this journey and that others have faced similar challenges.
#
# 노드 ID: 34
# Reflection: Sitting in the hospital waiting room always brings a mix of anxiety and frustration. I can’t help but feel a bit overwhelmed by the rows of chairs filled with other patients, all of us waiting for answers and support. The uncomfortable seating adds to my discomfort, and it makes me question how much care and attention we really receive in moments like these.
#
# 노드 ID: 35
# Reflection: I find myself drawn to content that resonates with my emotions and experiences, especially when it features vibrant visuals that capture my attention. The way different articles connect and weave together stories makes me feel understood and less alone in my journey. It's comforting to engage with material that not only entertains but also offers insights into my own struggles and triumphs.
#
# 노드 ID: 36
# Reflection: As I navigate through these experiences, I often feel a mix of hope and heaviness. The vivid colors I see seem to mirror my emotions—bright moments of optimism intertwined with the darker shades of my struggles. Observing others who share this journey brings a sense of connection, reminding me that even in our tiredness, there’s a flicker of hope we can cling to together.
#
# 노드 ID: 37
# Reflection: Being in a hospital can feel overwhelming, and the constant buzz of conversations around me only adds to that sense of unease. The uncomfortable seating reminds me of my physical pain, making it hard to focus on anything else. I find some comfort in the informative posters, though; they serve as a small reminder that I'm not alone in this journey and that there are resources and support available to help me through my struggles.
#
# 노드 ID: 38
# Reflection: I've been really trying to make sense of everything I've been going through lately. The techniques and routines I've been practicing feel like a lifeline, helping me navigate my mood and pain while I work on reducing my sleep medication. It’s comforting to reflect on how these experiences connect, as if they’re guiding me toward a little more peace and understanding in this chaotic time.
#
# 노드 ID: 39
# Reflection: During my time at the hospital, I felt a mix of anxiety and hope. The uncomfortable seating reminded me of my physical pain, but seeing other patients with tired yet hopeful expressions made me realize I’m not alone in this struggle. It’s a constant battle between feeling overwhelmed by my circumstances and finding moments of resilience, especially as I navigate my health and the emotional weight of it all.
#
# 노드 ID: 40
# Reflection: I've been thinking a lot about my therapy session and the techniques I learned. It's empowering to realize that I can integrate those exercises into my daily routine, which feels like a step toward taking control of my back pain and improving my sleep. I’m hopeful that with consistent practice, I can find some relief and maybe even lift my mood a little more each day.
#
# 노드 ID: 41
# Reflection: Lately, I've been finding a sense of calm in the small sounds around me, like the gentle settling of my home. It’s comforting to tune into my breath, feeling the rise and fall, which helps me stay grounded amidst the chaos of my thoughts and worries. These moments of awareness, whether it’s the warmth of a blanket or the quiet hum of life around me, really enhance my overall well-being and remind me to be present, even when things feel overwhelming.
#
# 노드 ID: 42
# Reflection: I've been feeling a mix of hope and heaviness lately. While I try to focus on the positive techniques I've learned to manage my pain and insomnia, there's an underlying weight from the depression that sometimes makes it hard to fully embrace those moments of reflection and meditation. It's a journey of balancing my emotions, and I often find myself just wishing for a bit of peace amidst the chaos.
#
# 노드 ID: 43
# Reflection: I’ve noticed that integrating those exercises into my daily routine has really helped me feel more grounded and in control, especially with everything going on. Reflecting on my progress gives me a sense of accomplishment that lifts my spirits, and even the simple act of organizing my space feels like a small victory that makes my life feel a bit lighter. It’s amazing how something as mundane as washing can become a source of calm; it’s almost meditative and reminds me to take things one step at a time.
#
# 노드 ID: 44
# Reflection: As I sit here, I can’t help but feel how the gentle sounds of my home settling around me bring a sense of calm that contrasts sharply with the chaos in my mind. The changing scenery outside the car window reminds me of how fluid life is, and it nudges me to reflect on my journey with breast cancer and the emotional weight I've been carrying. Each sound and sight pulls me deeper into my thoughts, helping me sift through my feelings of anxiety and pain, guiding me toward more mindful decisions about my well-being and the steps I want to take moving forward.
#
# 노드 ID: 45
# Reflection: I find that when I focus on my breath and the simple rhythms of daily tasks, like washing dishes, I can really tap into a sense of calm. It's almost like those moments become a sanctuary for me, where I can let go of the pain and heaviness I often feel. Just noticing the stillness in the room and my breathing helps me feel more centered and at peace, even if just for a brief moment.
#
# 노드 ID: 46
# Reflection: I find myself leaning heavily on self-care as a way to navigate the challenges I'm facing. Simple routines, like keeping things clean and organized, have become my little moments of mindfulness, helping me feel more grounded amidst the chaos. It's like I'm telling myself that these small acts of care can bring some peace, even when my back pain and mood feel overwhelming.
#
# 노드 ID: 47
# Reflection: I’ve been noticing how much my environment impacts my mood and focus lately. When I’m in a calm space with soft music, it feels easier to reflect on my experiences and absorb the recommendations I’ve received. But when there’s noise or distractions around me, it’s like my thoughts scatter, and I struggle to find clarity amidst the chaos. It’s frustrating, especially when I’m trying to manage my pain and sleep issues.
#
# 노드 ID: 48
# Reflection: I find myself in a constant battle with my thoughts, trying to cultivate a sense of calm amidst the chaos. It feels like I'm grasping for moments of peace through simple activities, like washing or daydreaming, hoping they can anchor me and ease the weight of my worries. There’s a sense of hope that if I can just relax my mind, even for a moment, it might help me break free from this cycle of insomnia and pain.
#
# 노드 ID: 49
# Reflection: I find a surprising sense of peace in the simple act of washing dishes. The rhythmic movement of scrubbing and rinsing feels almost meditative, allowing me to focus on the present moment rather than the heaviness of my worries. There's something satisfying about transforming a pile of dirty dishes into a clean, orderly space—it gives me a small sense of accomplishment amidst the chaos of everything else I'm facing.
#
# 노드 ID: 50
# Reflection: I've found that taking a moment to appreciate nature really helps me feel more grounded. Whispering to myself about the beauty around me and focusing on calmness allows me to escape the heaviness of my thoughts, even if just for a little while. Engaging in simple activities, like washing dishes, turns into a soothing rhythm that brings me a sense of peace amidst everything I'm dealing with.
#
# 노드 ID: 51
# Reflection: As I navigate through these thoughts, I often feel a mix of anxiety and frustration. It’s overwhelming to consider all the tasks ahead, especially with the persistent back pain and the shadow of depression looming over me. I find myself wanting to take control, to visualize my day and make sense of it all, but sometimes the weight of it all makes me feel stuck, like I’m just going through the motions without really living.
#
# 노드 ID: 52
# Reflection: I find myself really craving moments of relaxation amidst the chaos of my thoughts and the discomfort in my back. It feels like a small victory when I can take a few minutes to breathe deeply and focus on calmness, even if it's just a brief escape. I know I need to prioritize these moments, as they help me regain a sense of control and peace, making it easier to face each day.
#
# 노드 ID: 53
# Reflection: I've been finding solace in my quiet moments, and it's amazing how much they help me appreciate the little things around me, like nature and engaging stories. My self-talk has become a comforting way to process my feelings, almost like having a gentle conversation with myself. It feels like each reflection deepens my understanding of what I’m going through, allowing me to embrace the beauty in my experiences, even amidst the challenges.
#
# 노드 ID: 54
# Reflection: I find myself drifting into daydreams and contemplating what I've read, almost like a way to escape the heaviness I’ve been feeling. It’s a mix of longing for peace and a bit of anxiety about my schedule, but in those moments, I can almost picture a calmer version of my life. It feels like my mind is searching for a break from the pain and worries that have been weighing me down.
#
# 노드 ID: 55
# Reflection: I've noticed that when I whisper or speak softly to myself while reading, it helps me connect with the material on a deeper level. It’s like giving my thoughts a voice, which makes the complex parts feel more manageable and engaging. Sometimes, it feels comforting to articulate my feelings and thoughts, especially when I'm dealing with everything that's been going on with my health and mood.
#
# 노드 ID: 56
# Reflection: I've been realizing how much physical relaxation and stretching can really shift my mood and clarity throughout the day. When I take the time to focus on relaxing my muscles and maintaining flexibility, it feels like I'm not just easing my back pain, but also lifting a weight off my mind. It's almost like creating a calm space within myself, allowing me to approach each moment with a clearer head and a little more peace.
#
# 노드 ID: 57
# Reflection: In these quiet moments, I find that my appreciation for nature and my surroundings is deeply influenced by my current state of mind and the ongoing challenges I face. The gentle sounds and tranquil atmosphere feel like a soothing balm, helping to ease my worries and lift my spirits, even if just a little. It's as if the beauty around me invites me to pause, breathe, and reconnect with a sense of peace that often feels out of reach.
#
# 노드 ID: 58
# Reflection: I find myself really needing to focus on what’s important each day, especially with everything going on. I visualize my schedule in my mind, breaking down tasks into manageable pieces so I don’t feel overwhelmed. It helps to whisper each task to myself; it feels like I’m giving my brain a little nudge to remember what I need to do, which brings me a sense of calm amidst the chaos.
#
# 노드 ID: 59
# Reflection: When I'm shopping for ingredients, I'm really motivated by a desire to eat healthily and support my overall well-being, especially given my health challenges. I tend to assess quality by looking for freshness and vibrant colors, like the bright orange of fresh carrots or the deep green of peas. I also consider the price because I want to make sure I'm getting good value without compromising on what I put into my body.
#
# 노드 ID: 60
# Reflection: I felt a wave of calm wash over me when I heard those harmonious chords; it was like a gentle reminder that beauty still exists, even amidst my struggles. It lifted my spirits a bit, making me more eager to embrace the day and tackle the tasks ahead, like going to the market. Music has this incredible way of soothing my mind, especially when I'm feeling overwhelmed by everything else.
#
# 노드 ID: 61
# Reflection: I find myself really prioritizing freshness and quality when I shop for produce lately. It feels like a small way to take control of my health amidst everything else I'm dealing with, especially with the challenges of my back pain and mood. Selecting vibrant, fresh vegetables not only lifts my spirits but also reminds me to nourish my body as best as I can.
#
# 노드 ID: 62
# Reflection: Shopping at the market feels like a breath of fresh air for me, a little escape from the heaviness that often surrounds my daily life. As I walk through the aisles and browse the stalls, I find a sense of purpose and connection, not just to the vibrant food around me, but to the community of people bustling about. It’s a small, yet significant part of my routine that lifts my spirits and reminds me that there’s still joy to be found in the simple things.
#
# 노드 ID: 63
# Reflection: I felt the need to establish a routine for shopping and meal preparation because it gives me a sense of control amidst everything else that's been overwhelming lately. Cooking has become a comforting activity for me, a way to nurture myself and create something positive, especially when my mood feels low. It’s also a chance to focus on my health and well-being, which feels so important right now.
#
# 노드 ID: 64
# Reflection: I truly believe that a clean cooking environment is essential for my overall health and well-being, especially given my current struggles. When I tidy up and wipe down surfaces, it feels like I'm taking control of my space and, in a way, my life. It's comforting to know that by maintaining cleanliness, I'm not just creating a pleasant atmosphere but also protecting myself from potential germs and keeping my spirits lifted amidst everything I'm dealing with.
#
# 노드 ID: 65
# Reflection: When I'm at the market selecting fresh produce, I find myself really paying attention to the quality and freshness of the items. It’s not just about what looks good; I also think about how these choices can impact my health, especially with everything I've been going through. There’s a sense of empowerment in choosing vibrant, healthy foods, but I can’t help but feel a bit overwhelmed by the options and the prices, wanting to make sure I’m getting the best for my well-being.
#
# 노드 ID: 66
# Reflection: When I’m at the market, I often feel a mix of determination and anxiety as I navigate my choices. I want to make healthy selections that support my well-being, especially given my health challenges, but I also find myself second-guessing whether I'm choosing the best options. It’s a balancing act between wanting to nourish myself and the nagging worry about whether I’m doing enough for my body.
#
# 노드 ID: 67
# Reflection: When I’m out shopping for produce, I can’t help but feel a sense of urgency about choosing the freshest items. It’s like a little ritual for me; I check each piece carefully, hoping to find the ones that not only look good but also feel right in my hands. I want to make sure I’m nourishing myself well, especially with everything I’m dealing with, and it gives me a small sense of control amidst the chaos.
#
# 노드 ID: 68
# Reflection: Meal preparation and consumption have become such meaningful moments for me lately. I find that savoring each bite not only brings me joy but also offers a chance to reflect on my day and my journey. It’s like a little ritual where I can appreciate the flavors and the effort I put into creating a clean, inviting space, which in turn helps lift my mood and gives me a sense of accomplishment.
#
# 노드 ID: 69
# Reflection: I've been really focusing on creating a sense of order and cleanliness in my evenings, and it's surprisingly uplifting. Preparing a satisfying dinner feels like a small victory, and sharing those moments with loved ones makes everything feel more meaningful. I’m learning to appreciate the little achievements, like tidying up or enjoying a meal together, as they help me feel grounded and accomplished despite the challenges I'm facing.
#
# 노드 ID: 70
# Reflection: Lately, I've been really leaning into the idea that a clean and organized space can have a profound impact on my mood and overall well-being. I find myself feeling more at ease when everything around me is tidy, and it’s almost like a little ritual that helps me manage my stress and anxiety. Engaging with social media also offers a sense of connection and distraction, but I try to balance it with moments of mindfulness to keep my mind from spiraling into negativity.
#
# 노드 ID: 71
# Reflection: I find that engaging with food and cleaning brings a sense of control and calm amidst the chaos of my health struggles. When I tidy up after eating, it feels like I'm creating a little sanctuary for myself, and it helps ease some of the weight on my mind. Watching those intriguing images online also sparks a bit of joy and curiosity, reminding me that there are still beautiful things in the world worth focusing on, even when everything feels overwhelming.
#
# 노드 ID: 72
# Reflection: I find that keeping my living space clean and organized gives me a sense of control in a time when so much feels overwhelming. It’s comforting to know that I can create a calming environment for myself, especially when I'm dealing with my back pain and insomnia. Plus, a tidy space just makes everything feel a bit lighter and more manageable, which is something I really need right now.
#
# 노드 ID: 73
# Reflection: I find myself navigating through a mix of urgency and distraction as I check notifications and emails, almost like a way to escape my racing thoughts. It's a bit overwhelming, yet there's a sense of accomplishment when I organize everything, even if it’s just a small victory in my day. I often wonder if this digital chaos is a healthy way to cope with my insomnia and back pain, or if it just adds to the noise in my mind.
#
# 노드 ID: 74
# Reflection: Lately, I've found myself really leaning into different ways to absorb information. I whisper key points to help them stick in my mind, and I calmly repeat subjects to reinforce what I've learned. It feels like a small but meaningful way to take control of my situation and engage with the material, especially when my mood feels low and my back pain makes it hard to focus.
#
# 노드 ID: 75
# Reflection: Lately, I find myself drawn to exploring new content and browsing through social media. It feels comforting to connect with others, especially when I like posts that resonate with my experiences. I often get lost in articles that offer insights or support related to my health journey, which helps me feel a little less alone in all of this.
#
# 노드 ID: 76
# Reflection: I've found that engaging my senses really helps me grasp and remember things better. When I hear music or snippets of conversations, it sparks my imagination and creates vivid images in my mind, almost like a movie playing out. It’s fascinating how these sensory experiences can transform my thoughts into something tangible, making it easier to hold onto the information I want to remember.
#
# 노드 ID: 77
# Reflection: I find comfort in the connections I make online, especially when I see those little digital thumbs-ups; it feels like a reminder that I’m not alone in this. Sharing joyous moments, even if it's just through social media, helps lift my spirits and distracts me from the pain and worries that weigh me down. It’s like finding a little spark of happiness amidst everything else, and that connection is so important for my emotional well-being.
#
# 노드 ID: 78
# Reflection: I've been feeling a mix of curiosity and hope lately, wanting to dive into topics that can help me cope with my cancer journey and the challenges of insomnia and back pain. Engaging with new content feels like a way to reclaim some control over my life, sparking ideas and possibilities that inspire me. It’s comforting to know that I’m not just passively experiencing my situation, but actively seeking knowledge and strategies that could improve my well-being.
#
# 노드 ID: 79
# Reflection: Lately, I've noticed that the sounds and images swirling in my mind create a sort of vivid tapestry that helps me process everything I'm going through. It's like each note of music or snippet of conversation adds depth to my thoughts, making them feel more real and easier to remember. I find comfort in these experiences, as they allow me to escape for a moment and connect with my feelings in a way that feels both grounding and freeing.
#
# 노드 ID: 80
# Reflection: I often find myself feeling overwhelmed and disconnected when I interact with technology, especially during those moments of disengagement. It’s like a wave of loneliness washes over me, amplifying my struggles with depression and insomnia. I crave meaningful connections, yet the screens can feel cold and distant, leaving me yearning for genuine support and understanding in my life.
#
# 노드 ID: 81
# Reflection: As I sit with my thoughts, I feel a mix of hope and uncertainty swirling within me. The music in the distance somehow lifts my spirits, sparking ideas about my future and what’s possible, yet I can’t shake the weight of my past experiences. Reflecting on everything, I find myself critiquing my journey, trying to connect the dots between my struggles and the potential paths ahead, but there’s still that lingering sense of sadness that shadows my progress.
#
# 노드 ID: 82
# Reflection: As I sit here, I can't help but notice how the sounds and images around me weave together into a tapestry of memories and emotions. The distant music and snippets of conversation spark something deep within, making me feel more connected to my surroundings and even to my past experiences. It's almost as if these sensory moments pull me out of my struggles, allowing me to momentarily escape the weight of my pain and insomnia, and instead, immerse myself in a vivid, engaging world that feels alive and meaningful.
#
# 노드 ID: 83
# Reflection: Lately, I've found myself deeply contemplating my choices and the paths I can take moving forward. There's this yearning for clarity and understanding as I navigate my health challenges, and I often catch myself reflecting on what truly matters to me—like finding relief from my pain and fostering a sense of peace in my mind. It's a mix of hope and frustration, as I try to balance my need for healing with the desire to regain control over my life without relying on medication.
#
# 노드 ID: 84
# Reflection: I've been feeling a mix of determination and introspection lately. It's like I'm sifting through layers of my thoughts, trying to find clarity and relief amidst the struggles with my health and sleep. There’s this focused energy pushing me to confront my feelings, which feels empowering, even if it’s all a bit overwhelming at times.
#
# 노드 ID: 85
# Reflection: I've been feeling this deep sense of struggle as my body and mind seem to be at odds with each other. The pain in my back makes it hard to find comfort, and it’s like my environment is echoing my internal chaos—everything feels heavy and burdensome. Yet, amidst all this, there are moments where I catch glimpses of hope, where I can almost visualize a path toward healing and balance, reminding me that I can reshape my experience if I just keep pushing forward.
#
# 노드 ID: 86
# Reflection: I've been feeling so overwhelmed lately, and I realize how much I crave connection and support from those I trust. Reaching out to my friend feels like a way to break through the isolation that my struggles with cancer, depression, and pain have created. I just want to share my feelings and memories, hoping it will help lift my mood and remind me that I'm not alone in this journey.
#
# Reflection 데이터가 ../output/reflections_persona0.txt 파일에 저장되었습니다.

# %%
# import json

# # File path for the uploaded JSON file
# file_path = "../output/shortterm_5min.json"

# # JSON 파일 열기 및 'description' 추출
# try:
#     with open(file_path, 'r', encoding='utf-8') as file:
#         data = json.load(file)
    
#     # Extract all descriptions from the JSON data
#     descriptions = [node.get("description", "") for node in data.values()]
    
#     # Save the descriptions to a new file or return them for user
#     output_file_path = "../output/descriptions_extracted.txt"
#     with open(output_file_path, 'w', encoding='utf-8') as output_file:
#         output_file.write("\n".join(descriptions))
    
#     output_message = f"Descriptions extracted successfully. File saved at: {output_file_path}"
# except Exception as e:
#     output_message = f"An error occurred: {str(e)}"

# output_message

# %%
# import json

# # JSON 파일 경로
# file_path = '../data/dummy_dataset/5min_dummy_data_merge.json'

# # JSON 파일 읽기
# with open(file_path, 'r', encoding='utf-8') as file:
#     data = json.load(file)

# # 'activity' 키의 개수 세기
# activity_count = sum(1 for item in data if 'activity' in item)

# print(f"'activity' 항목의 총 개수: {activity_count}")
